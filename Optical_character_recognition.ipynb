# %% [markdown]
# <a href="https://colab.research.google.com/github/alihammadbaig/OCR/blob/master/Optical_character_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Tesseract Library for OCR

# %%
# !pip install pdf2image
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random

from IPython.display import Image as Img

from google.colab import files

try:
 from PIL import Image
except ImportError:
 import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-89428b06-d52f-4417-8c9f-467f11c4afb4" name="files[]" multiple disabled />
#      <output id="result-89428b06-d52f-4417-8c9f-467f11c4afb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hello_world.PNG to hello_world (2).PNG

# %%
Img("hello_world.PNG", width=200, height=50)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('hello_world.PNG'))

print(extractedInformation)
# Out:
# 1 Hello world!

# %% [markdown]
# ## Lets try a bit more complicated image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-71a0dc74-411d-47a2-a203-e3fb9925c6c4" name="files[]" multiple disabled />
#      <output id="result-71a0dc74-411d-47a2-a203-e3fb9925c6c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Capture.PNG to Capture (2).PNG

# %%
Img("Capture.PNG", width=400, height=250)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('Capture.PNG'))

print(extractedInformation)
# Out:
# 1 $031109 M146 + 1SA0-HK-~ 107 123 102 124 106 112 209 224 238 247 210 226 04-Nov-14
#
# yy) 320113 ee” 118 111 118 113 112 202 219 233 203 219 215 Q4-Nov-14 @5-N
# 3 $046836, A2EB-582 . +3 7 112 122 107 122 105 114 213 223 242 246 214 228 Q4-Nov-14 @'
#
# 4 5014458 A2EA*S92,/PG015+2SCO-05 7 106 101 114 101 109 106 206 228 237 205 209 217 04-Nov-14 @5
#
# 5 $042449 A2E1+SS2 AMQO5-1SA0-19 7 101 117 103 117 112 110 201 218 232 250 218 224 Q4-Nov-14 05
#
# 6 $013917 A2EA-712 WSQQ8-1SA0-05 7 111 121 112 121 104 114 210 222 241 202 213 218 @4-Nov-14 05
#
# 7 $024105+ CAE8-420 PGOO8-1S80-Q2 7 105 100 108 125 114 110 205 227 236 245 217 226 @4-Nov-14 O
#
# 8 $020443 C7EA-410 PG159-1S80-02 7 100 116 115 116 108 111 200 217 231 204 208 212 @4-Nov-14 05
#
# 9 SQ1S848+ A2E8-602 MRO14-6SB0-06 7 108 120 104 120 111 113 211 221 240 249 212 227 @4-Nov-14 O
#
# 10 $@19248 A2EL-S52 AM142-1SA0.06 7 110 125 113 123 103 115 208 226 235 201 216 217 @4-Nov-14 @'
#
# ...

# %% [markdown]
# ## A bit more complicated image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-75ee31ab-748e-4e7d-8a01-68d1edaa8519" name="files[]" multiple disabled />
#      <output id="result-75ee31ab-748e-4e7d-8a01-68d1edaa8519">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image-20190319-011157.png to image-20190319-011157 (5).png

# %%
Img("image-20190319-011157.png", width=400, height=200)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('image-20190319-011157.png'))
print(extractedInformation)
# Out:
# %Livy2.pyspark
# spark.sql("use default")
#
# spark.sql( ‘show tables’).show()
# spark.read.table(‘synthetic_test’).show()
#
# +
# |database| tablelame|isTemporary|
#
#
#
# +
# | default|synthetic_test| false|
#
#
#
#
#
# I name|gender| patientid| birthdate|countryofresidence|
#
#
#
# [Brittany Johnson] F|@01-02-6218|28/12/1919| Australial4 /

# %% [markdown]
# ## Lets increase the complexity

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14e966de-877e-4be5-a868-4c946f7e0b01" name="files[]" multiple disabled />
#      <output id="result-14e966de-877e-4be5-a868-4c946f7e0b01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving complex_image.PNG to complex_image.PNG

# %%
Img("complex_image.PNG", width=600, height=400)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('complex_image.PNG'))
print(extractedInformation)
# Out:
# PROJECT NO.
#
# TCHTHYS ONSHORE LNG FACILITIES PROJECT
# ‘STPBl MODULE FABRICATION YARD - THAILAND.
#
# COATING APPLICATION ACCEPTANCE REPORT
#
# 10789-0-5
#
# REPORT NO.
#
# N2.1.2 Page 5479 of 13699
#
# QC-PTG-IT-06350
#
#
#
# IM \EFABRICATOR
#
# [STP&i Public Company Limited
#
# REPORT DATE
#
# 06-Nov-14
#
#
#
# CONG SPECIFICATION
#
# L290-AL-SPC-10008
#
# COATING SYSTEM NO.
#
# Z
#
#
#
# IDRAWING / ISOMETRIC
#
# Environmental conditions & Surface temperature
#
# SURFACE PREPARATION
#
# JAs Per item Description
# ly log sheets verified
#
# ‘SUBSTRATE [please encircle)
#
# \d within project specification requirements YES/NO
#
# CS{Ss HOG / Aluminium / others
#
#
#
# WELD FABRICATION DEFECTS RECTIFIED (YES/NO)
#
# YES
#
# BLOTTER TEST (YES/NO}
#
# YES
#
#
#
# ISURFACE PREPARATION METHOD
#
#
#
# Abrasive Blast
#
# ABRASIVE TYPE
#
# Garnet 30/60
#
#
#
# |SURFACE PREPARATION GRADE
#
# Light Sweep Blast
#
# [ABRASIVE BATCH NO.
#
# FGA 04140920
#
#
#
# [SURFACE PROFILE RANGE (microns)
#
# ...

# %% [markdown]
# ## Yeah, I know, this is almost impossible

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f302604-44f8-46a8-b65e-3daeb0d649d7" name="files[]" multiple disabled />
#      <output id="result-4f302604-44f8-46a8-b65e-3daeb0d649d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vivid.jpg to vivid.jpg

# %%
Img("vivid.jpg", width=600, height=400)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('vivid.jpg'))
print(extractedInformation)
# Out:
# fae)
#
# ae
#
#
#
# i
#
# F
#
# en bl to dot alah te
# ic
#
# chai bila ery
#
# ae) 1
#
# ed Rat
#
# , eee
# abi BS haan ey ee Taare!
#
# Le tert s
# Screer, Cla slg
#
# PC GMa ak
# aT at
#
# any n Play CUS Limba ars eh]
# a ng ies ana re oe Saat “ware manuf
#
# vi He ee :
#
# aed A Soe) EN ter ae Ca See
#
# Problems , SONtin el
#
# es Noe oy ee MedNet Heian Gree Unt LUC ney
# REM [eye Ich ¢ BSE a
# cali a nS a Nea ee tart et aati Ba boot
# you need ie Sa nse * Star i
# Coca a rr
# AES
#
#
#
#
#
#
#
#
#
#
#
# Sac uemeT t) ss
# = bah
#
# eel it BUC E a tt eae t
# ee Bee ocr ta ey RT ea ee
# Mesa Eris) es iene ;
# 4
#
# eapeee'|
#
#
#
#
#
# esuee: . ime yoy
# 5 the Fir St t
# CTT ete Ti a ales
# an
#
# ae aa
# sea Hee ctheeaa tet
# are rr pe att pele)
#
# a Seat ete disab
#
#
#
#
#
#
#
#
#
#
#
# oe ee een toy
# ~ Ee eek ar
# = 0 us Ei
